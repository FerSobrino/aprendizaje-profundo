# %% [markdown]
# ## Tarea 8: Transformers
#
#
# Instrucciones:
# 1. Ponle de nombre a tu tarea `tarea_8.ipynb` un Jupyter Notebook (5 points)
# 2. Escribe tu nombre comleto y tus iniciales en tu notebook después de la siguiente nota:
# *Este trabajo es mio y sigue la integridad académica del Tec. de Monterrey*
# 3. Agrega los nombres de todos los compañeros con los que trabajaste. Recuerda que puedes discutir con tus compañeros pero cada quien tiene que entregar su tarea.
# 4. **ADVERTENCIA!** no se permite el uso de LLMs para estas tareas! El aprendizaje profundo no va a hacer la tarea de aprendizaje profundo... Si no entienden bien los conceptos no hay diferencia entre ustedes y el LLM y esto es sad, se mueren las hadas cuando hacen esto :(
# 5. Asegurate que tu código corra!
# 6. Las preguntas de teoria contestalas en texto usando markdown, no comentarios en python

# %% [markdown]
# 1. ¿Cómo escala el costo computacional con la dimensionalidad de keys, queries, values y su número? ¿Qué pasa con los requerimientos de ancho de banda de memoria?
#
# 2. Supongamos que tenemos un modelo entrenado basado en multi-head attention y queremos podar (prune) las cabezas menos importantes para aumentar la velocidad de predicción. ¿Cómo podemos diseñar experimentos para medir la importancia de una cabeza de atención?
#
# 3. Supongamos que diseñamos una arquitectura profunda para representar una secuencia apilando capas de self-attention con codificación posicional. ¿Qué problemas podrían surgir?
#
# 4. ¿Es buena idea reemplazar la atención scaled dot-product con atención aditiva en el Transformer? ¿Por qué?
#
# 5. ¿Qué desafíos enfrentan los Transformers si las secuencias de entrada son muy largas? ¿Por qué?
#
# 6. Digamos que queremos ajustar (fine-tune) un modelo de lenguaje para clasificación de texto añadiendo capas adicionales. ¿Dónde las añadimos? ¿Por qué?
#
# 7. Consideremos problemas secuencia-a-secuencia (ej. traducción automática) donde la secuencia de entrada está siempre disponible durante la predicción. ¿Qué limitaciones tiene modelar con Transformers decoder-only? ¿Por qué?

# %% [markdown]
# ### python:
#
# Reporta los resultados de los ejercicios rápidos al final del notebook de transformers, pega acá tu código y asegurate que corra para todos los ejeplos.
